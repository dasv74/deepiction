# %% [markdown]
# ##### Deepiction V.0.4
#
# ## **Test Dataset**
#
# *File structure*
# - training
#     - sources
#     - targets
# - test
#     - sources
#     - targets

# %%
from deepiction.imagedataset import ImageDataset
from interactive_kit import imviewer
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore")

#dataname, norm = 'simulation-object-256-8-2', ('minmax', 'none')
#dataname, norm = 'simulation-dmap-256-8-1', ('minmax', 'none')
#dataname, norm = 'simulation-class-256-8-3', ('minmax', 'none')
#dataname, norm = 'degradation-noisy-p50', ('none', 'none')
#dataname, norm = 'simulation-binary-256-8-1', ('minmax', 'none')
dataname, norm = 'ctc-glioblastoma', ('minmax', 'none')

# Define the dataset path
print('Current path:', os.path.abspath(os.getcwd()))
datapath  = '../datasets/' + dataname
print('Path ', datapath)

# Number of images to load
nb = 5
norm = ('minmax', 'minmax')
color = False
dataset = ImageDataset(datapath, 'train/sources', 'train/targets')
dataset.load(nb, norm, color)

# Display a pair of image source-target
num = 2
a = dataset.sources[num,:,:,0]
b = dataset.targets[num,:,:,0]
fig, axs = plt.subplots(1, 2)
axs[0].imshow(a, cmap='gray')
axs[0].set_title('Source ' + str(num))
axs[1].imshow(b, cmap='gray')
axs[1].set_title('Target ' + str(num))
plt.show()
# Out:
# Current path: /Users/sage/Desktop/deepiction/current
# Path  ../datasets/ctc-glioblastoma
#
# Dataset folders: pairs of images
# ../datasets/ctc-glioblastoma/train/sources number of images: 66 files
# ../datasets/ctc-glioblastoma/train/targets number of images: 66 files
