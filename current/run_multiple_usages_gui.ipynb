# %% [markdown]
# ##### Deepiction V.0.5
#
# ## **Train and Test Deep Neural Networks**
# - Tensorflow: unet, resnet
# - Pytorch: unet_ten, unet_n2n

# %%
import numpy as np
import os
from deepiction.manager import load_model, create_model, create_model_gui, print_model, create_report
from deepiction.imagedataset import ImageDataset
from deepiction.test import Test
from deepiction.training import Training
from deepiction.tools import Tools

Tools.resources()
# Out:
# Resources
# Current path: /Users/sage/Desktop/deepiction/current
# GPU available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow Version:  2.11.0
# device mps
# Pytorch GPU available:  mps

# %% [markdown]
# **2. Selection of the dataset**
# - task
#     - binary: pixel classification, input 1 grayscale channel, output mask class=0 or class=1
#     - nclass: pixel classification in n class, input 1 grayscale channel, output labels
#     - regress: regression, input 1 grayscale channel, output 1 grayscale channel
# - norm: (training, test), minmax, div255, none

# %%
#dataname, task, norm, color = 'simulation-object-256-8-2', 'nclass', ('minmax', 'none'), False
#dataname, task, norm, color = 'simulation-dmap-256-8-1', 'regres', ('minmax', 'none'), False
#dataname, task, norm, color = 'simulation-class-256-8-3', 'nclass', ('minmax', 'none'), False
dataname, task, norm, color = 'degradation-noisy-p50', 'regres', ('none', 'none'), False
#dataname, task, norm, color = 'simulation-binary-256-8-1', 'binary', ('minmax', 'none'), False
#dataname, task, norm, color = 'ctc-glioblastoma', 'binary', ('minmax', 'none'), False
#dataname, task, norm, color = 'lr2hr', 'regres', ('none', 'none'), True

datapath  = os.path.join('..', 'datasets', dataname)
dataset = ImageDataset(datapath, 'train/sources', 'train/targets')

#dataset.load(50, norm, color)
dataset.load_gui(200, norm, color)
# Out:
# Dataset folders: pairs of images
# ../datasets/degradation-noisy-p50/train/sources number of images: 80 files
# ../datasets/degradation-noisy-p50/train/targets number of images: 80 files
# VBox(box_style='info', children=(HTML(value='<style> th, td { padding: 3px; } .dataframe { background-color: w…

# %%
# Visualisation of the sources images and the targets images
Tools.interactive_display(dataset.sources, dataset.targets, transparency=0.8)
# Out:
# VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=384, width=384),)),)), IntSlider(value=40, des…

# %%
#netname = 'PT_unet'
#netname = 'PT_dncnn'
#netname = 'TF_resnet'
netname = 'TF_unet'

npools, nchannels, batchnorm, dropout = 3, 32, False, 0
noutputs, ninputs = 1, 1
imagesize = dataset.get_image_size()

task = 'regres'
if task == 'binary': activation, loss, acc = 'sigmoid', 'bce', 'mse'
if task == 'nclass': activation, loss, acc = 'softmax', 'categorical_crossentropy', 'accuracy' 
if task == 'regres': activation, loss, acc = 'relu', 'mse', 'mae'

if task == 'nclass': dataset.makeClassesAsChannels()

#create_model_gui(imagesize, noutputs, ninputs, nchannels, npools, dropout, batchnorm, activation)

model = create_model(netname, imagesize, ninputs, noutputs, nchannels, npools, activation=activation)

#model = load_model(os.path.join('..', 'reports', dataname, 'TF_unet-3P-32C-4E-0.001LR', 'model_best_1.hdf5'))
# Out:
# TF Build architecture TF_unet (batchnorm: False dropout: 0)

# %%
# Check the model
print_model(model)
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 384, 384, 1  0           []
#                                 )]
#
#  conv2d_30 (Conv2D)             (None, 384, 384, 32  320         ['input_3[0][0]']
#                                 )
#
#  activation_30 (Activation)     (None, 384, 384, 32  0           ['conv2d_30[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 384, 384, 32  9248        ['activation_30[0][0]']
#                                 )
#
#  activation_31 (Activation)     (None, 384, 384, 32  0           ['conv2d_31[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 192, 192, 32  0          ['activation_31[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 192, 192, 64  18496       ['max_pooling2d_6[0][0]']
#                                 )
#
#  activation_32 (Activation)     (None, 192, 192, 64  0           ['conv2d_32[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 192, 192, 64  36928       ['activation_32[0][0]']
#                                 )
#
#  activation_33 (Activation)     (None, 192, 192, 64  0           ['conv2d_33[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 96, 96, 64)  0           ['activation_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 96, 96, 128)  73856       ['max_pooling2d_7[0][0]']
#
#  activation_34 (Activation)     (None, 96, 96, 128)  0           ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 96, 96, 128)  147584      ['activation_34[0][0]']
#
#  activation_35 (Activation)     (None, 96, 96, 128)  0           ['conv2d_35[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 48, 48, 128)  0          ['activation_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 48, 48, 256)  295168      ['max_pooling2d_8[0][0]']
#
#  activation_36 (Activation)     (None, 48, 48, 256)  0           ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 48, 48, 256)  590080      ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 48, 48, 256)  0           ['conv2d_37[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 96, 96, 128)  131200     ['activation_37[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 96, 96, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'activation_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 96, 96, 128)  295040      ['concatenate_6[0][0]']
#
#  activation_38 (Activation)     (None, 96, 96, 128)  0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 96, 96, 128)  147584      ['activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 96, 96, 128)  0           ['conv2d_39[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 192, 192, 64  32832      ['activation_39[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 192, 192, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_33[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 192, 192, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  activation_40 (Activation)     (None, 192, 192, 64  0           ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 192, 192, 64  36928       ['activation_40[0][0]']
#                                 )
#
#  activation_41 (Activation)     (None, 192, 192, 64  0           ['conv2d_41[0][0]']
#                                 )
#
#  conv2d_transpose_8 (Conv2DTran  (None, 384, 384, 32  8224       ['activation_41[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 384, 384, 64  0           ['conv2d_transpose_8[0][0]',
#                                 )                                 'activation_31[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 384, 384, 32  18464       ['concatenate_8[0][0]']
#                                 )
#
#  activation_42 (Activation)     (None, 384, 384, 32  0           ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 384, 384, 32  9248        ['activation_42[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 384, 384, 32  0           ['conv2d_43[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 384, 384, 1)  289         ['activation_43[0][0]']
#
#  activation_44 (Activation)     (None, 384, 384, 1)  0           ['conv2d_44[0][0]']
#
# ==================================================================================================
# Total params: 1,925,281
# Trainable params: 1,925,281
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **4. Training**

# %%
epochs, batchsize, learningrate = 40, 16, 0.001
trainname = f'{netname}-{npools}P-{nchannels}C-{epochs}E-{learningrate}LR'
path = os.path.join('../reports', dataname, trainname)
print('Report path:', path)

training = Training(dataset, model, path, split_validation=0.25)
report_training = training.train(epochs, 16, 0.001, loss, acc)
# Out:
# Report path: ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR
# Training set: (60,60) images
# Validation set: (20,20) images
# Epoch 1/40
# 4/4 [==============================] - ETA: 0s - loss: 66708.3906 - mae: 156.5266
# Epoch 1: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 4s 754ms/step - loss: 66708.3906 - mae: 156.5266 - val_loss: 1172.3456 - val_mae: 25.7628
# Epoch 2/40
# 4/4 [==============================] - ETA: 0s - loss: 5757.0366 - mae: 59.2492
# Epoch 2: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 648ms/step - loss: 5757.0366 - mae: 59.2492 - val_loss: 10921.0713 - val_mae: 87.8546
# Epoch 3/40
# 4/4 [==============================] - ETA: 0s - loss: 10117.7471 - mae: 84.3662
# Epoch 3: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 682ms/step - loss: 10117.7471 - mae: 84.3662 - val_loss: 11934.9443 - val_mae: 92.1105
# Epoch 4/40
# 4/4 [==============================] - ETA: 0s - loss: 10336.0820 - mae: 85.4170
# Epoch 4: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 730ms/step - loss: 10336.0820 - mae: 85.4170 - val_loss: 11082.2139 - val_mae: 88.6124
# Epoch 5/40
# 4/4 [==============================] - ETA: 0s - loss: 9068.6445 - mae: 79.6959
# Epoch 5: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 689ms/step - loss: 9068.6445 - mae: 79.6959 - val_loss: 8544.0605 - val_mae: 77.3358
# Epoch 6/40
# 4/4 [==============================] - ETA: 0s - loss: 6383.4775 - mae: 66.0639
# Epoch 6: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 673ms/step - loss: 6383.4775 - mae: 66.0639 - val_loss: 4669.1489 - val_mae: 56.3596
# Epoch 7/40
# 4/4 [==============================] - ETA: 0s - loss: 2796.4165 - mae: 41.8415
# Epoch 7: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 727ms/step - loss: 2796.4165 - mae: 41.8415 - val_loss: 794.7138 - val_mae: 21.5543
# Epoch 8/40
# 4/4 [==============================] - ETA: 0s - loss: 720.5172 - mae: 19.6163
# Epoch 8: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 706ms/step - loss: 720.5172 - mae: 19.6163 - val_loss: 1540.4834 - val_mae: 33.1581
# Epoch 9/40
# 4/4 [==============================] - ETA: 0s - loss: 1375.2008 - mae: 30.7465
# Epoch 9: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 701ms/step - loss: 1375.2008 - mae: 30.7465 - val_loss: 886.3843 - val_mae: 24.2525
# Epoch 10/40
# 4/4 [==============================] - ETA: 0s - loss: 618.5466 - mae: 18.3453
# Epoch 10: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 731ms/step - loss: 618.5466 - mae: 18.3453 - val_loss: 379.3498 - val_mae: 12.3379
# Epoch 11/40
# 4/4 [==============================] - ETA: 0s - loss: 427.7093 - mae: 13.5787
# Epoch 11: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 739ms/step - loss: 427.7093 - mae: 13.5787 - val_loss: 516.2842 - val_mae: 16.5375
# Epoch 12/40
# 4/4 [==============================] - ETA: 0s - loss: 509.3240 - mae: 15.9380
# Epoch 12: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 862ms/step - loss: 509.3240 - mae: 15.9380 - val_loss: 450.1318 - val_mae: 14.9630
# Epoch 13/40
# 4/4 [==============================] - ETA: 0s - loss: 405.7004 - mae: 13.2132
# Epoch 13: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 405.7004 - mae: 13.2132 - val_loss: 376.9276 - val_mae: 12.6900
# Epoch 14/40
# 4/4 [==============================] - ETA: 0s - loss: 408.4114 - mae: 13.5078
# Epoch 14: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 408.4114 - mae: 13.5078 - val_loss: 373.2102 - val_mae: 12.7115
# Epoch 15/40
# 4/4 [==============================] - ETA: 0s - loss: 372.1722 - mae: 12.3832
# Epoch 15: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 372.1722 - mae: 12.3832 - val_loss: 358.1544 - val_mae: 12.3742
# Epoch 16/40
# 4/4 [==============================] - ETA: 0s - loss: 366.6915 - mae: 12.3998
# Epoch 16: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 366.6915 - mae: 12.3998 - val_loss: 348.9959 - val_mae: 12.1982
# Epoch 17/40
# 4/4 [==============================] - ETA: 0s - loss: 348.4369 - mae: 11.9317
# Epoch 17: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 348.4369 - mae: 11.9317 - val_loss: 326.0654 - val_mae: 11.5448
# Epoch 18/40
# 4/4 [==============================] - ETA: 0s - loss: 330.3831 - mae: 11.5919
# Epoch 18: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 330.3831 - mae: 11.5919 - val_loss: 310.3568 - val_mae: 11.2784
# Epoch 19/40
# 4/4 [==============================] - ETA: 0s - loss: 311.0076 - mae: 11.2072
# Epoch 19: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 311.0076 - mae: 11.2072 - val_loss: 292.1505 - val_mae: 10.9714
# Epoch 20/40
# 4/4 [==============================] - ETA: 0s - loss: 289.8868 - mae: 10.8918
# Epoch 20: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 289.8868 - mae: 10.8918 - val_loss: 274.9269 - val_mae: 10.6727
# Epoch 21/40
# 4/4 [==============================] - ETA: 0s - loss: 266.1052 - mae: 10.4948
# Epoch 21: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 266.1052 - mae: 10.4948 - val_loss: 250.8341 - val_mae: 10.2624
# Epoch 22/40
# 4/4 [==============================] - ETA: 0s - loss: 242.2847 - mae: 10.1111
# Epoch 22: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 242.2847 - mae: 10.1111 - val_loss: 232.4650 - val_mae: 10.0511
# Epoch 23/40
# 4/4 [==============================] - ETA: 0s - loss: 221.0398 - mae: 9.8547
# Epoch 23: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 221.0398 - mae: 9.8547 - val_loss: 216.7423 - val_mae: 9.9442
# Epoch 24/40
# 4/4 [==============================] - ETA: 0s - loss: 206.6490 - mae: 9.7802
# Epoch 24: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 206.6490 - mae: 9.7802 - val_loss: 207.5680 - val_mae: 9.9215
# Epoch 25/40
# 4/4 [==============================] - ETA: 0s - loss: 196.2137 - mae: 9.7003
# Epoch 25: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 196.2137 - mae: 9.7003 - val_loss: 196.4146 - val_mae: 9.7722
# Epoch 26/40
# 4/4 [==============================] - ETA: 0s - loss: 187.0218 - mae: 9.5652
# Epoch 26: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 187.0218 - mae: 9.5652 - val_loss: 187.6232 - val_mae: 9.6286
# Epoch 27/40
# 4/4 [==============================] - ETA: 0s - loss: 179.2082 - mae: 9.4263
# Epoch 27: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 179.2082 - mae: 9.4263 - val_loss: 181.3640 - val_mae: 9.5341
# Epoch 28/40
# 4/4 [==============================] - ETA: 0s - loss: 173.7741 - mae: 9.3349
# Epoch 28: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 173.7741 - mae: 9.3349 - val_loss: 173.8614 - val_mae: 9.3767
# Epoch 29/40
# 4/4 [==============================] - ETA: 0s - loss: 167.3535 - mae: 9.1909
# Epoch 29: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 167.3535 - mae: 9.1909 - val_loss: 167.5500 - val_mae: 9.2819
# Epoch 30/40
# 4/4 [==============================] - ETA: 0s - loss: 164.4844 - mae: 9.1991
# Epoch 30: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 164.4844 - mae: 9.1991 - val_loss: 164.5190 - val_mae: 9.3261
# Epoch 31/40
# 4/4 [==============================] - ETA: 0s - loss: 159.0087 - mae: 9.1126
# Epoch 31: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 159.0087 - mae: 9.1126 - val_loss: 156.4916 - val_mae: 9.1173
# Epoch 32/40
# 4/4 [==============================] - ETA: 0s - loss: 155.5371 - mae: 9.0298
# Epoch 32: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 5s 1s/step - loss: 155.5371 - mae: 9.0298 - val_loss: 153.8094 - val_mae: 9.0752
# Epoch 33/40
# 4/4 [==============================] - ETA: 0s - loss: 152.7780 - mae: 8.9627
# Epoch 33: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 794ms/step - loss: 152.7780 - mae: 8.9627 - val_loss: 151.8866 - val_mae: 9.0258
# Epoch 34/40
# 4/4 [==============================] - ETA: 0s - loss: 150.5785 - mae: 8.9042
# Epoch 34: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 730ms/step - loss: 150.5785 - mae: 8.9042 - val_loss: 149.3672 - val_mae: 8.9580
# Epoch 35/40
# 4/4 [==============================] - ETA: 0s - loss: 148.8052 - mae: 8.8610
# Epoch 35: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 743ms/step - loss: 148.8052 - mae: 8.8610 - val_loss: 147.3261 - val_mae: 8.9013
# Epoch 36/40
# 4/4 [==============================] - ETA: 0s - loss: 147.3974 - mae: 8.8288
# Epoch 36: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 747ms/step - loss: 147.3974 - mae: 8.8288 - val_loss: 145.7141 - val_mae: 8.8597
# Epoch 37/40
# 4/4 [==============================] - ETA: 0s - loss: 146.0518 - mae: 8.7943
# Epoch 37: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 743ms/step - loss: 146.0518 - mae: 8.7943 - val_loss: 145.0745 - val_mae: 8.8444
# Epoch 38/40
# 4/4 [==============================] - ETA: 0s - loss: 144.7714 - mae: 8.7555
# Epoch 38: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 756ms/step - loss: 144.7714 - mae: 8.7555 - val_loss: 144.7392 - val_mae: 8.8409
# Epoch 39/40
# 4/4 [==============================] - ETA: 0s - loss: 143.5024 - mae: 8.7209
# Epoch 39: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 760ms/step - loss: 143.5024 - mae: 8.7209 - val_loss: 143.9784 - val_mae: 8.8272
# Epoch 40/40
# 4/4 [==============================] - ETA: 0s - loss: 142.1883 - mae: 8.6866
# Epoch 40: saving model to ../reports/degradation-noisy-p50/TF_unet-3P-32C-40E-0.001LR/model_best_0.hdf5
# 4/4 [==============================] - 3s 771ms/step - loss: 142.1883 - mae: 8.6866 - val_loss: 142.2756 - val_mae: 8.7782

# %% [markdown]
# **5. Test**

# %%
# Load test data
dataset = ImageDataset(datapath, 'test/sources', 'test/targets')
dataset.load(10, norm, color)
dataset.report
# Out:
# Dataset folders: pairs of images
# ../datasets/degradation-noisy-p50/test/sources number of images: 23 files
# ../datasets/degradation-noisy-p50/test/targets number of images: 23 files
# <bound method ImageDataset.report of <deepiction.imagedataset.ImageDataset object at 0x3f71a9220>>

# %%
test = Test(model)
report_test = test.run(dataset, 'psnr', path)
create_report(path)
# Out:
# Start prediction
# 1/1 [==============================] - 0s 193ms/step
# Prediction input(10, 384, 384, 1)
# PSNR 182.79173278808594 65535.96093750582
# PSNR 555.9106383032288 65535.96093750582
# PSNR 70.59065246582031 65025.0
# PSNR 560.746732788086 65025.0
# PSNR 178.32696533203125 65025.0
# PSNR 582.1384486219617 65025.0
# PSNR 135.4390869140625 65025.0
# PSNR 703.270513305664 65025.0
# PSNR 110.05950164794922 52900.0
# PSNR 556.0144952392578 52900.0
# PSNR 188.5631561279297 65025.0
# PSNR 580.4772825113932 65025.0
# PSNR 154.88002014160156 65025.0
# PSNR 458.0822182210286 65025.0
# PSNR 152.85357666015625 52441.0
# PSNR 448.794205593533 52441.0
# PSNR 85.98687744140625 65025.0
# PSNR 475.83969760470933 65025.0
# PSNR 150.8776092529297 65025.0
# PSNR 580.5305121527779 65025.0

# %%
# Visualisation of the targets images and the predictions images
Tools.interactive_display(dataset.sources, test.predictions)
# Out:
# VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=384, width=384),)),)), IntSlider(value=5, desc…
